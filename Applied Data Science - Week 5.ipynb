# %% [markdown]
# Problem Statement: Locate best MRT location for a new bubble tea shop in Singapore
#
# Background: Singapore is populated with bubble tea shops, find best location for a new bubble tea shop with fewest number of bubble tea shops

# %%
import requests # library to handle requests
import pandas as pd # library for data analsysis
import numpy as np # library to handle data in a vectorized manner
import random # library for random number generation

from geopy.geocoders import Nominatim # module to convert an address into latitude and longitude values

# libraries for displaying images
from IPython.display import Image 
from IPython.core.display import HTML 
    
# tranforming json file into a pandas dataframe library
from pandas.io.json import json_normalize

# %%
CLIENT_ID = 'YF5TJRRDLDNAXYCTY42K5SIC4HUOCX5EWAQKSMOSZKALP2X4' # your Foursquare ID
CLIENT_SECRET = 'DET1ECZGBBMHOYHKWC242MVALE2WRBSSUBYM52WUHC10ZKP0' # your Foursquare Secret
ACCESS_TOKEN = '01B1XVCYPGJ3BQG40CHQEVKXTJAKYJQO3VPY0VRB5Z4MZ4B2' # your FourSquare Access Token
VERSION = '20180604'
LIMIT = 100
print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: YF5TJRRDLDNAXYCTY42K5SIC4HUOCX5EWAQKSMOSZKALP2X4
# CLIENT_SECRET:DET1ECZGBBMHOYHKWC242MVALE2WRBSSUBYM52WUHC10ZKP0

# %%
address = 'Aljunied, Singapore'

geolocator = Nominatim(user_agent="foursquare_agent")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print(latitude, longitude)
# Out:
# 1.3164515 103.8829087

# %%
search_query = '52e81612bcbc57f1066b7a0c'
radius = 1500
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&oauth_token={}&v={}&categoryId={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude,ACCESS_TOKEN, VERSION, search_query, radius, LIMIT)
results = requests.get(url).json()

# %%
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=YF5TJRRDLDNAXYCTY42K5SIC4HUOCX5EWAQKSMOSZKALP2X4&client_secret=DET1ECZGBBMHOYHKWC242MVALE2WRBSSUBYM52WUHC10ZKP0&ll=1.3164515,103.8829087&oauth_token=01B1XVCYPGJ3BQG40CHQEVKXTJAKYJQO3VPY0VRB5Z4MZ4B2&v=20180604&categoryId=52e81612bcbc57f1066b7a0c&radius=1500&limit=100'

# %%
results
# Out:
# {'meta': {'code': 200, 'requestId': '60f6c5ada4bf057a740bf36c'},
#  'notifications': [{'type': 'notificationTray', 'item': {'unreadCount': 44}}],
#  'response': {'venues': [{'id': '5d68ea5fc79f3b0008f18931',
#     'name': 'Playmade',
#     'location': {'address': '#B2-K5 PLQ Mall',
#      'crossStreet': '10 Paya Lebar Road',
#      'lat': 1.3172834,
#      'lng': 103.89282,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 1.3172834,
#        'lng': 103.89282}],
#      'distance': 1106,
#      'cc': 'SG',
#      'city': 'Singapore',
#      'country': 'Singapore',
#      'formattedAddress': ['#B2-K5 PLQ Mall (10 Paya Lebar Road)',
#       'Singapore']},
#     'categories': [{'id': '52e81612bcbc57f1066b7a0c',
#       'name': 'Bubble Tea Shop',
#       'pluralName': 'Bubble Tea Shops',
#       'shortName': 'Bubble Tea',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bubble_',
#        'suffix': '.png'},
#       'primary': True}],
# ...

# %%
venues = results['response']['venues']
dataframe = json_normalize(venues)
dataframe
# Out:
# <ipython-input-61-eef7b28d3e48>:2: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   dataframe = json_normalize(venues)
#                           id                   name  \
# 0   5d68ea5fc79f3b0008f18931               Playmade
# 1   5a0aaf4e65cdf837cf6c742e                   LiHO
# 2   5a5b5471b399f74bd7ca0522                  i.tea
# 3   5f7c1b6ff97f9d0e2a3aa65e                   Liho
# 4   5d6cb2c7e74a210008d4a20b            Milksha 迷客夏
# 5   5e3a8a3e4d818a00081572d5                Koi Thé
# 6   5d9891cc5b55b10008befb5a              Hopii 何必問
# 7   5e59f17628630a0008d9717c           Xing Fu Tang
# 8   6097752e87ea854b093465cc          The Alley 鹿角巷
# 9   5e33d6e7167c1c0007176a07               Gong Cha
# 10  5db65984707fcc0008c3b129   Chicha San Chen 吃茶三千
# 11  5bf27e57971317002d727e33                R&B Tea
# 12  60e12dc61621f37a5bba20a1  Chinese Tofu Magician
# 13  5d69122d9704a7000836a748               Li Ho 哩喝
# ...

# %%
# keep only columns that include venue name, and anything that is associated with location
filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dataframe_filtered['categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dataframe_filtered.columns = [column.split('.')[-1] for column in dataframe_filtered.columns]

dataframe_filtered
# Out:
#                      name       categories                         address  \
# 0                Playmade  Bubble Tea Shop                 #B2-K5 PLQ Mall
# 1                    LiHO  Bubble Tea Shop     80 Geylang Lorong 25 #01-04
# 2                   i.tea  Bubble Tea Shop       #01-50, Paya Lebar Square
# 3                    Liho  Bubble Tea Shop          5, Sims Avenue, #01-03
# 4             Milksha 迷客夏  Bubble Tea Shop                 #03-25 PLQ Mall
# 5                 Koi Thé  Bubble Tea Shop        Paya Lebar Quarter B1-02
# 6               Hopii 何必問  Bubble Tea Shop                        #01-107A
# 7            Xing Fu Tang  Bubble Tea Shop               Paya Lebar Square
# 8           The Alley 鹿角巷  Bubble Tea Shop                             NaN
# 9                Gong Cha  Bubble Tea Shop           Paya Lebar Quarter B1
# 10   Chicha San Chen 吃茶三千  Bubble Tea Shop                 #02-27 PLQ Mall
# ...

# %%
dataframe_filtered
# Out:
#                      name       categories                         address  \
# 0                Playmade  Bubble Tea Shop                 #B2-K5 PLQ Mall
# 1                    LiHO  Bubble Tea Shop     80 Geylang Lorong 25 #01-04
# 2                   i.tea  Bubble Tea Shop       #01-50, Paya Lebar Square
# 3                    Liho  Bubble Tea Shop          5, Sims Avenue, #01-03
# 4             Milksha 迷客夏  Bubble Tea Shop                 #03-25 PLQ Mall
# 5                 Koi Thé  Bubble Tea Shop        Paya Lebar Quarter B1-02
# 6               Hopii 何必問  Bubble Tea Shop                        #01-107A
# 7            Xing Fu Tang  Bubble Tea Shop               Paya Lebar Square
# 8           The Alley 鹿角巷  Bubble Tea Shop                             NaN
# 9                Gong Cha  Bubble Tea Shop           Paya Lebar Quarter B1
# 10   Chicha San Chen 吃茶三千  Bubble Tea Shop                 #02-27 PLQ Mall
# ...
